# %% [markdown]
# # LOC & ILOC

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflix_titles.csv")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # LOC

# %%
# data.loc[<row labels>, <column labels>]
data.loc[:,["type"]].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
data.loc[:,["type", "date_added"]].value_counts()
# Out:
# type     date_added
# Movie    January 1, 2020      97
#          November 1, 2019     75
#          March 1, 2018        72
#          December 31, 2019    67
#          October 1, 2018      64
#                               ..
# TV Show  December 18, 2017     1
# Movie    November 12, 2018     1
#          December 8, 2019      1
#          November 12, 2019     1
# TV Show  September 9, 2021     1
# Length: 2584, dtype: int64

# %%
data.loc[data["title"]=="Kota Factory"]
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
arr = data.loc[1,"cast"].split(", ")

# %%
arr = data.loc[1,"cast"].split(", ")
print(arr)
# Out:
# ['Ama Qamata', 'Khosi Ngema', 'Gail Mabalane', 'Thabang Molaba', 'Dillon Windvogel', 'Natasha Thahane', 'Arno Greeff', 'Xolile Tshabalala', 'Getmore Sithole', 'Cindy Mahlangu', 'Ryle De Morny', 'Greteli Fincham', 'Sello Maake Ka-Ncube', 'Odwa Gwanya', 'Mekaila Mathys', 'Sandi Schultz', 'Duane Williams', 'Shamilla Miller', 'Patrick Mofokeng']

# %%
data.loc[1,"cast"]
# Out:
# 'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng'

# %%
len(arr)
# Out:
# 19

# %%
data.loc[data.release_year>=2020].count()
# Out:
# show_id         1545
# type            1545
# title           1545
# director         845
# cast            1321
# country         1235
# date_added      1545
# release_year    1545
# rating          1545
# duration        1545
# listed_in       1545
# description     1545
# dtype: int64

# %% [markdown]
# # Add col in existing dataset

# %% [markdown]
# # Col_of cast_num of cast Assignment here

# %%
data['num of cast']=data['cast'].replace(np.nan,'0')
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q1 Assignment add col new_cast

# %%
data.fillna(0)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water                0
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                0
# 4         s5  TV Show           Kota Factory                0
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb                0
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.fillna(0, inplace=True)

def new_cast(self):
    
    
    for i in range( 1 , len(data)):
        return len(data.loc[ i , "cast"].split(", "))
    i = i + 1

# %%
data["new_cast"] = data["cast"].apply(new_cast)
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water                0
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans                0
# 4      s5  TV Show           Kota Factory                0
#
#                                                 cast        country  \
# 0                                                  0  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...              0
# 3                                                  0              0
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # ILOC

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.iloc[1:8]
# Out:
#   show_id     type                             title  \
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                         director  \
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
#
#                                                 cast  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# ...

# %%
data.iloc[[7]]
# Out:
#   show_id   type    title      director  \
# 7      s8  Movie  Sankofa  Haile Gerima
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
#
#    release_year rating duration  \
# 7          1993  TV-MA  125 min
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
#
#                                          description
# 7  On a photo shoot in Ghana, an American model s...

# %%
data["cast"]= data['director'].replace(np.nan, "none")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                  cast        country          date_added  release_year rating  \
# 0     Kirsten Johnson  United States  September 25, 2021          2020  PG-13
# ...

# %% [markdown]
# # GROUP BY

# %%
data.head()
# Out:
#   show_id     type                  title         director             cast  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN             none
# 2      s3  TV Show              Ganglands  Julien Leclercq  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN             none
# 4      s5  TV Show           Kota Factory              NaN             none
#
#          country          date_added  release_year rating   duration  \
# 0  United States  September 25, 2021          2020  PG-13     90 min
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2            NaN  September 24, 2021          2021  TV-MA   1 Season
# 3            NaN  September 24, 2021          2021  TV-MA   1 Season
# 4          India  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# ...

# %%
data.groupby("type")["duration"].value_counts()
# Out:
# type     duration
# Movie    90 min        152
#          93 min        146
#          94 min        146
#          97 min        146
#          91 min        144
#                       ...
# TV Show  13 Seasons      3
#          11 Seasons      2
#          12 Seasons      2
#          15 Seasons      2
#          17 Seasons      1
# Name: duration, Length: 220, dtype: int64

# %%
data1= data.groupby("type")
data1['duration'].value_counts()
# Out:
# type     duration
# Movie    90 min        152
#          93 min        146
#          94 min        146
#          97 min        146
#          91 min        144
#                       ...
# TV Show  13 Seasons      3
#          11 Seasons      2
#          12 Seasons      2
#          15 Seasons      2
#          17 Seasons      1
# Name: duration, Length: 220, dtype: int64

# %%
type(data1)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
data.groupby("type").groups
# Out:
# {'Movie': [0, 6, 7, 9, 12, 13, 16, 18, 22, 23, 24, 26, 27, 28, 29, 30, 35, 36, 38, 41, 42, 43, 44, 45, 46, 48, 51, 52, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 68, 71, 73, 75, 77, 78, 79, 80, 81, 84, 86, 88, 90, 91, 93, 94, 96, 101, 103, 105, 107, 112, 113, 114, 115, 116, 117, 118, 119, 122, 126, 127, 128, 129, 130, 131, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 149, 150, 151, 152, 155, 156, 157, 158, 159, 161, 162, ...], 'TV Show': [1, 2, 3, 4, 5, 8, 10, 11, 14, 15, 17, 19, 20, 21, 25, 31, 32, 33, 34, 37, 39, 40, 47, 49, 50, 55, 65, 66, 67, 69, 70, 72, 74, 76, 82, 83, 85, 87, 89, 92, 95, 97, 98, 99, 100, 102, 104, 106, 108, 109, 110, 111, 120, 121, 123, 124, 125, 132, 147, 148, 153, 154, 160, 165, 181, 184, 186, 187, 189, 193, 194, 197, 198, 212, 213, 218, 219, 220, 222, 223, 224, 225, 226, 232, 234, 241, 242, 243, 245, 248, 254, 260, 263, 265, 266, 269, 271, 272, 273, 274, ...]}

# %% [markdown]
# # Q2 FOR COUNT TV SHOWS & MOVIES

# %%
print(data['type'].value_counts())

#using groupby

data.groupby(['type']).size()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64
# type
# Movie      6131
# TV Show    2676
# dtype: int64
